# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim import corpora
from gensim.models import LdaModel

# Download required resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/9bd7767f-e2b1-4f3e-a47c-80a0c1669bd6/nltk_data..
# [nltk_data]     .
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/9bd7767f-e2b1-4f3e-a47c-80a0c1669bd6/nltk_data..
# [nltk_data]     .
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
documents = [
    "Rafael Nadal Joins Roger Federer in Missing U.S. Open",
    "Rafael Nadal Is Out of the Australian Open",
    "Biden Announces Virus Measures",
    "Biden's Virus Plans Meet Reality",
    "Where Biden's Virus Plan Stands"
]

# %%
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalnum()]  # remove punctuation
    tokens = [word for word in tokens if word not in stop_words]  # remove stopwords
    return tokens

processed_docs = [preprocess(doc) for doc in documents]

print(processed_docs)
# Out:
# [['rafael', 'nadal', 'joins', 'roger', 'federer', 'missing', 'open'], ['rafael', 'nadal', 'australian', 'open'], ['biden', 'announces', 'virus', 'measures'], ['biden', 'virus', 'plans', 'meet', 'reality'], ['biden', 'virus', 'plan', 'stands']]

# %%
dictionary = corpora.Dictionary(processed_docs)
corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

print(corpus)
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1)], [(3, 1), (4, 1), (5, 1), (7, 1)], [(8, 1), (9, 1), (10, 1), (11, 1)], [(9, 1), (11, 1), (12, 1), (13, 1), (14, 1)], [(9, 1), (11, 1), (15, 1), (16, 1)]]

# %%
lda_model = LdaModel(corpus=corpus, num_topics=2, id2word=dictionary, passes=10)

# %%
# Print topics
topics = lda_model.print_topics()
for topic in topics:
    print(topic)
# Out:
# (0, '0.157*"virus" + 0.157*"biden" + 0.067*"plan" + 0.067*"stands" + 0.067*"measures" + 0.067*"plans" + 0.067*"meet" + 0.067*"reality" + 0.067*"announces" + 0.029*"federer"')
# (1, '0.128*"nadal" + 0.128*"open" + 0.128*"rafael" + 0.079*"australian" + 0.073*"joins" + 0.072*"roger" + 0.072*"missing" + 0.072*"federer" + 0.028*"biden" + 0.028*"virus"')
